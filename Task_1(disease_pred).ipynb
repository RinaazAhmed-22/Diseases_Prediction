# %%
print("=====AI Diagnosis Assistant Activated=====")
fever=input("Do you have fever:")
cough=input("Do you have cough:")
sta=input("Do you have stomach ache:")
hd=input("Do you headache:")
ft=input("Do you feel fatigue/tiredness:")
vom=input("Do you have vomiting:")
cht=input("Do you have chest pain:")
bd=input("Do you have breathing difficuly:")
bp=input("Do yoi have body pain:")
et=input("Do you feel excessive thirst:")
fu=input("do you have frequent urination:")
so=input("Do you have sore throat:")
dz=input("Do you feel dizziness:")
cold=input("Do you have cold/shivering:")
print("ANALYZING SYMPTOMS......")

if (cough== "yes" and so=="yes" and fever=="yes"):
  print("You have common cold")
  print("Severity: Mild")

elif(fever=="yes" and bp=="yes" and hd=='yes' and ft=='yes'):
  print("You have Flu")
  print("Severity: Moderate")

elif(fever=='yes' and bp=='yes' and cough=='yes' and ft=='yes'):
  print("You have COVID-like infection")
  print("Severity: Severe")
  print("Suggestion:Consult the doctor IMMEDIATELY!!!!")

elif(fever=='yes' and sta=='yes' and vom=='yes' ):
  print("You have Food Poisioning")
  print("Severity: Moderate")

elif(hd=='yes' and dz=='yes' and vom=='yes'):
  print("You have Migraine")
  print("Severity: Moderate")

elif(et=='yes'  and fu=='yes' and ft=='yes'):
  print("You have Diabetes Risk")
  print("Severity: Moderate")
  print("Suggestion:Consult doctor")

elif(fever=='yes' and bp=='yes' and hd=='yes' and vom=='yes'):
  print("You have Dengue-like Symptoms")
  print("Severity: Moderate")
  print("Suggestion:Consult doctor")
elif(fever=='yes' and cold=='yes' and hd=='yes'):
  print("You have Malaria-like Symptoms")
  print("Severity: Moderate")
  print("Suggestion:Consult doctor")
elif(sta=='yes' and vom=='yes'):
  print("You have Gastric Problem")
  print("Severity: Moderate")
elif(bd=='yes' and cough=='yes'):
  print("You have Asthma Risk")
  print("Severity: Severe")
  print("Suggestion:Consult the doctor IMMEDIATELY!!!!")
elif(et=='yes' and ft=='yes' and dz=='yes'):
  print("You have Dehydrated")
  print("Severity: Mild")
else:
  print("You are healthy!!!!")
# Out:
# =====AI Diagnosis Assistant Activated=====
# Do you have fever:yes
# Do you have cough:yes
# Do you have stomach ache:no
# Do you headache:no
# Do you feel fatigue/tiredness:no
# Do you have vomiting:no
# Do you have chest pain:no
# Do you have breathing difficuly:no
# Do yoi have body pain:no
# Do you feel excessive thirst:no
# do you have frequent urination:no
# Do you have sore throat:yes
# Do you feel dizziness:no
# Do you have cold/shivering:no
# ANALYZING SYMPTOMS......
# You have common cold
# Severity: Mild
